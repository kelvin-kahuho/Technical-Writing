# %% [markdown]
# # Data Visualization.
#
# ## Prerequisites: Guide, Introduction to Matplotlib.
#
# Data visualization is a crucial part of data analysis. It allows us to transform complex datasets into understandable and insightful visuals. In this blog post, we'll explore different types of plots and provide examples of how to create them using synthetic data. Whether you're a data scientist, analyst, or just someone curious about data, this guide will help you harness the power of data visualization.

# %% [markdown]
# ## Table of Contents
#
# 1. Introduction
# 2. Line Plot
# 3. Scatter Plot
# 4. Bar Plot
# 5. Histogram
# 6. Box Plot
# 7. Pie Chart
# 8. Conclusion

# %% [markdown]
# ## Introduction
#
# Before diving into specific plot types, let's understand the importance of data visualization. Effective visualization can help you:
#
# Spot Trends and Patterns: Visualizations reveal trends, patterns, and anomalies that might be hidden in raw data.
#
# Communicate Insights: Well-designed plots make it easier to convey your findings to others, whether it's a team, stakeholders, or the public.
#
# Inform Decision-Making: Visualizations assist in making data-driven decisions.
#
# Now, let's explore some common types of plots and create examples using synthetic data.

# %% [markdown]
# ## Line Plot
#
# Purpose: Line plots are ideal for showing trends over a continuous interval or time series data.
#
# Example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create synthetic data
x = np.linspace(0, 10, 100)
print(x)
y = np.sin(x)
print(y)

# Create a line plot
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %% [markdown]
# ## Scatter Plot
#
# Purpose: Scatter plots display individual data points, making them useful for showing relationships between two variables.
#
# Example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create synthetic data
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot
plt.scatter(x, y, marker='x')
plt.title("Random Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ## Bar Plot
#
# Purpose: Bar plots are suitable for comparing categories or groups.
#
# Example:

# %%
import matplotlib.pyplot as plt

# Create synthetic data
categories = ['A', 'B', 'C', 'D']
values = [51, 12, 86, 43]

# Create a bar plot
plt.bar(categories, values)
plt.title("Bar Plot Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## Histogram
#
# Purpose: Histograms show the distribution of a single variable.
#
# Example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create synthetic data
data = np.random.normal(0, 1, 1000)

# Create a histogram
plt.hist(data, bins=30)
plt.title("Histogram of Random Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Box Plot
#
# Purpose: Box plots display the distribution and variability of a dataset.
#
# Example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create synthetic data
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Create a box plot
plt.boxplot(data, labels=['1', '2', '3'])
plt.title("Box Plot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Pie Chart
#
# Purpose: Pie charts represent parts of a whole, useful for displaying proportions.
#
# Example:

# %%
import matplotlib.pyplot as plt

# Create synthetic data
labels = ['A', 'B', 'C', 'D', 'E']
sizes = [96, 30, 45, 10, 1]

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# Conclusion
#
# Data visualization is a powerful tool for exploring, understanding, and communicating data. In this blog post, we've covered several common types of plots and provided examples using synthetic data. These examples should serve as a starting point for your data visualization journey. As you dive deeper into the world of data, you'll discover even more sophisticated and insightful ways to visualize your data.
